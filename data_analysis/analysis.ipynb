# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd "/content/drive/MyDrive/qiita-love/data_analysis"
# Out:
# /content/drive/MyDrive/qiita-love/data_analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD
import pickle

# %%
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 100)

# %%
# 1月から12月までのデータを読み込んで結合しdfに格納
df = pd.DataFrame()
for i in range(1, 13):
    df_tmp = pd.read_csv(f"../data_collection/data/2020-{i:02}.csv", encoding="utf8")
    df = pd.concat([df, df_tmp], ignore_index=True)
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# セル5 を c:\Users\Ryo Yanagimoto\qiita-love\data_analysis\analysis.ipynb in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Ryo%20Yanagimoto/qiita-love/data_analysis/analysis.ipynb#W4sZmlsZQ%3D%3D?line=1'>2</a> df = pd.DataFrame()
#       <a href='vscode-notebook-cell:/c%3A/Users/Ryo%20Yanagimoto/qiita-love/data_analysis/analysis.ipynb#W4sZmlsZQ%3D%3D?line=2'>3</a> for i in range(1, 13):
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Ryo%20Yanagimoto/qiita-love/data_analysis/analysis.ipynb#W4sZmlsZQ%3D%3D?line=3'>4</a>     df_tmp = pd.read_csv(f"../data_collection/data/2020-{i:02}.csv", encoding="utf8")
#       <a href='vscode-notebook-cell:/c%3A/Users/Ryo%20Yanagimoto/qiita-love/data_analysis/analysis.ipynb#W4sZmlsZQ%3D%3D?line=4'>5</a>     df = pd.concat([df, df_tmp], ignore_index=True)
#       <a href='vscode-notebook-cell:/c%3A/Users/Ryo%20Yanagimoto/qiita-love/data_analysis/analysis.ipynb#W4sZmlsZQ%3D%3D?line=5'>6</a> df.head()
#
# File c:\Users\Ryo Yanagimoto\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File c:\Users\Ryo Yanagimoto\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     665 kwds_defaults = _refine_defaults_read(
#     666     dialect,
#     667     delimiter,
#    (...)
#     676     defaults={"delimiter": ","},
#     677 )
#     678 kwds.update(kwds_defaults)
# --> 680 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\Ryo Yanagimoto\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:575, in _read(filepath_or_buffer, kwds)
#     572 _validate_names(kwds.get("names", None))
#     574 # Create the parser.
# --> 575 parser = TextFileReader(filepath_or_buffer, **kwds)
#     577 if chunksize or iterator:
#     578     return parser
#
# File c:\Users\Ryo Yanagimoto\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:933, in TextFileReader.__init__(self, f, engine, **kwds)
#     930     self.options["has_index_names"] = kwds["has_index_names"]
#     932 self.handles: IOHandles | None = None
# --> 933 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\Ryo Yanagimoto\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:1217, in TextFileReader._make_engine(self, f, engine)
#    1213     mode = "rb"
#    1214 # error: No overload variant of "get_handle" matches argument types
#    1215 # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    1216 # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> 1217 self.handles = get_handle(  # type: ignore[call-overload]
#    1218     f,
#    1219     mode,
#    1220     encoding=self.options.get("encoding", None),
#    1221     compression=self.options.get("compression", None),
#    1222     memory_map=self.options.get("memory_map", False),
#    1223     is_text=is_text,
#    1224     errors=self.options.get("encoding_errors", "strict"),
#    1225     storage_options=self.options.get("storage_options", None),
#    1226 )
#    1227 assert self.handles is not None
#    1228 f = self.handles.handle
#
# File c:\Users\Ryo Yanagimoto\anaconda3\lib\site-packages\pandas\io\common.py:789, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     784 elif isinstance(handle, str):
#     785     # Check whether the filename is to be opened in binary mode.
#     786     # Binary mode does not support 'encoding' and 'newline'.
#     787     if ioargs.encoding and "b" not in ioargs.mode:
#     788         # Encoding
# --> 789         handle = open(
#     790             handle,
#     791             ioargs.mode,
#     792             encoding=ioargs.encoding,
#     793             errors=errors,
#     794             newline="",
#     795         )
#     796     else:
#     797         # Binary mode
#     798         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data_collection/data/2020-09.csv'

# %%
# dfの各カラムのデータ型を確認
df.dtypes
# Out:
# likes_count        float64
# title               object
# body                object
# created_date        object
# created_time        object
# tags                object
# followers_count    float64
# organization        object
# items_count        float64
# dtype: object

# %%
# dfの各カラムの欠損値の数を確認
df.isnull().sum()
# Out:
# likes_count             1
# title                   0
# body                    1
# created_date            1
# created_time            1
# tags                    1
# followers_count         2
# organization       110525
# items_count             2
# dtype: int64

# %%
### 変更箇所 ###
# organizationに値が入っていればTrue、欠損していればFalseに置き換える、さらに数値に変換する
df["organization"] = df["organization"].notnull().astype(int)
df.head()
# Out:
#    likes_count                                   title  \
# 0          1.0                      品質担保に本気で取り組んでみている話
# 1          5.0  【Unity】Screen.safeAreaとiOSステータスバーの罠（？）
# 2          3.0                   徹底攻略！“SATySFiのロゴ”の出し方
# 3          0.0               【KPI】家系図テーブルの操作 1【oracle】
# 4          0.0                       プログラミング・フォロを組み立てる
#
#                                                 body created_date  \
# 0  株式会社オズビジョンの @terra_yucco です。2020/01 現在、オズビジョン ...   2020-01-31
# 1  # Unityで取得できる Screen.safeAreaには罠（？）がある罠に遭遇したのは...   2020-01-31
# 2  **SATySFiのロゴ**といえば、もちろんコレですね。![image-1a.png](h...   2020-01-31
# 3  某炎の紋章の家系図見てて、TRPGなどに使えるかなと思って家系図テーブルの運用を考える。階層...   2020-01-31
# 4  #プログラミング・フォロmicro:bitを内蔵して６本足で自律して歩き回ることの出来る [...   2020-01-31
#
#   created_time                          tags  followers_count  organization  \
# 0     23:59:59   ['仕様', '品質管理', '品質', 'QCD']             43.0             1
# 1     23:56:36  ['iOS', 'Unity', 'SafeArea']              2.0             0
# 2     23:54:15                   ['SATySFi']            157.0             0
# 3     23:50:44                    ['oracle']              1.0             0
# 4     23:45:47   ['RaspberryPi', 'microbit']              3.0             0
#
#    items_count
# 0         97.0
# 1          7.0
# 2         65.0
# 3         10.0
# 4         11.0

# %%
# dfの各カラムの欠損値の数を確認
df.isnull().sum()
# Out:
# likes_count        1
# title              0
# body               1
# created_date       1
# created_time       1
# tags               1
# followers_count    2
# organization       0
# items_count        2
# dtype: int64

# %%
# 欠損値を含む行を削除
df = df.dropna()
# indexを振り直す
df = df.reset_index(drop=True)

# %%
# likes_countの値が1000以上の行を抽出
df[df["likes_count"] >= 1000].head()
# Out:
#       likes_count                              title  \
# 749        1386.0      Vue開発者のためのVue.jsベストプラクティス集15選
# 1008       1523.0    Vue.jsで作成された、ちょっと面白くて役立ちそうなサービス
# 1459       1024.0             FFT（高速フーリエ変換）を完全に理解する話
# 3500       1062.0  2020年現在 Web系企業で採用されてる技術についてまとめてみた
# 3868       4834.0                          良いコードの書き方
#
#                                                    body created_date  \
# 749   # はじめに**みなさん、Vue使ってますかー！**・・・・・・・（へんじがない。ただのしか...   2020-01-29
# 1008  ## [こちらに移行しました。(2020/05/16)](https://tech-blog...   2020-01-29
# 1459  FFT(Fast Fourier Transform),高速フーリエ変換についての記事です。...   2020-01-27
# 3500  # はじめに2020年も始まりましたね！タイトル通りですが、2020年現在スタートアップや大...   2020-01-22
# 3868  # 概要チームによる継続的開発を前提としたコーディングのガイドライン。特定の言語を対象とした...   2020-01-21
#
#      created_time                                               tags  \
# 749      23:00:56                   ['JavaScript', 'Vue.js', 'Nuxt']
# 1008     08:43:49  ['JavaScript', 'Bootstrap', 'ツール', 'Vue.js', '...
# 1459     22:00:06         ['アルゴリズム', 'math', 'AtCoder', '競技プログラミング']
# 3500     10:43:23        ['初心者', 'ツール', 'まとめ', '初心者向け', 'プログラミング言語']
# 3868     10:50:39  ['Java', 'プログラミング', 'コーディング規約', 'チーム開発', 'Swift']
#
#       followers_count  organization  items_count
# 749             131.0             0         15.0
# 1008             35.0             0         19.0
# 1459            163.0             0         28.0
# 3500             24.0             0         27.0
# 3868            128.0             1         29.0

# %%
# likes_countの値が1000以上なら1000に置き換える
df.loc[df["likes_count"] >= 1000, "likes_count"] = 1000
df[df["likes_count"] >= 1000].head()
# Out:
#       likes_count                              title  \
# 749        1000.0      Vue開発者のためのVue.jsベストプラクティス集15選
# 1008       1000.0    Vue.jsで作成された、ちょっと面白くて役立ちそうなサービス
# 1459       1000.0             FFT（高速フーリエ変換）を完全に理解する話
# 3500       1000.0  2020年現在 Web系企業で採用されてる技術についてまとめてみた
# 3868       1000.0                          良いコードの書き方
#
#                                                    body created_date  \
# 749   # はじめに**みなさん、Vue使ってますかー！**・・・・・・・（へんじがない。ただのしか...   2020-01-29
# 1008  ## [こちらに移行しました。(2020/05/16)](https://tech-blog...   2020-01-29
# 1459  FFT(Fast Fourier Transform),高速フーリエ変換についての記事です。...   2020-01-27
# 3500  # はじめに2020年も始まりましたね！タイトル通りですが、2020年現在スタートアップや大...   2020-01-22
# 3868  # 概要チームによる継続的開発を前提としたコーディングのガイドライン。特定の言語を対象とした...   2020-01-21
#
#      created_time                                               tags  \
# 749      23:00:56                   ['JavaScript', 'Vue.js', 'Nuxt']
# 1008     08:43:49  ['JavaScript', 'Bootstrap', 'ツール', 'Vue.js', '...
# 1459     22:00:06         ['アルゴリズム', 'math', 'AtCoder', '競技プログラミング']
# 3500     10:43:23        ['初心者', 'ツール', 'まとめ', '初心者向け', 'プログラミング言語']
# 3868     10:50:39  ['Java', 'プログラミング', 'コーディング規約', 'チーム開発', 'Swift']
#
#       followers_count  organization  items_count
# 749             131.0             0         15.0
# 1008             35.0             0         19.0
# 1459            163.0             0         28.0
# 3500             24.0             0         27.0
# 3868            128.0             1         29.0

# %%
# created_dateを今日から何日前に投稿されたかを表す数値に変換
df["created_date"] = pd.to_datetime(df["created_date"])
df["created_days_ago"] = (pd.to_datetime("today") - df["created_date"]).dt.days
df["created_month"] = df["created_date"].dt.month
df = df.drop("created_date", axis=1)
# created_timeを何時に投稿されたかに変換
df["created_time"] = df["created_time"].str[:2].astype(int)
df.head()
# Out:
#    likes_count                                   title  \
# 0          1.0                      品質担保に本気で取り組んでみている話
# 1          5.0  【Unity】Screen.safeAreaとiOSステータスバーの罠（？）
# 2          3.0                   徹底攻略！“SATySFiのロゴ”の出し方
# 3          0.0               【KPI】家系図テーブルの操作 1【oracle】
# 4          0.0                       プログラミング・フォロを組み立てる
#
#                                                 body  created_time  \
# 0  株式会社オズビジョンの @terra_yucco です。2020/01 現在、オズビジョン ...            23
# 1  # Unityで取得できる Screen.safeAreaには罠（？）がある罠に遭遇したのは...            23
# 2  **SATySFiのロゴ**といえば、もちろんコレですね。![image-1a.png](h...            23
# 3  某炎の紋章の家系図見てて、TRPGなどに使えるかなと思って家系図テーブルの運用を考える。階層...            23
# 4  #プログラミング・フォロmicro:bitを内蔵して６本足で自律して歩き回ることの出来る [...            23
#
#                            tags  followers_count  organization  items_count  \
# 0   ['仕様', '品質管理', '品質', 'QCD']             43.0             1         97.0
# 1  ['iOS', 'Unity', 'SafeArea']              2.0             0          7.0
# 2                   ['SATySFi']            157.0             0         65.0
# 3                    ['oracle']              1.0             0         10.0
# 4   ['RaspberryPi', 'microbit']              3.0             0         11.0
#
#    created_days_ago  created_month
# 0              1040              1
# 1              1040              1
# 2              1040              1
# 3              1040              1
# 4              1040              1

# %%
# 文の情報をTF-IDFでベクトル化してからSVDで10次元に削減する関数
def vectorize_text(text, n_components=20):
    tfidf = TfidfVectorizer()
    df_tfidf = tfidf.fit_transform(df[text])
    file = '../app/model_tfidf/trained_model_' + text + '.pkl'
    pickle.dump(tfidf, open(file, 'wb'))

    svd = TruncatedSVD(n_components=n_components)
    df_svd = svd.fit_transform(df_tfidf)
    file = f'../app/model_svd/trained_model_' + text + '.pkl'
    pickle.dump(svd, open(file, 'wb'))

    df_ret = pd.DataFrame(df_svd, columns=[f"{text}_{i}" for i in range(n_components)])
    return df_ret

# %%
# 文の情報をTF-IDFでベクトル化してからSVDで10次元に削減する関数(2回目以降)
def vectorize_text(text, n_components=20):
    file = '../app/model_tfidf/trained_model_' + text + '.pkl'
    tfidf = pickle.load(open(file, 'rb'))
    df_tfidf = tfidf.transform(df[text])
    pickle.dump(tfidf, open(file, 'wb'))

    file = f'../app/model_svd/trained_model_' + text + '.pkl'
    svd = pickle.load(open(file, 'rb'))
    df_svd = svd.transform(df_tfidf)
    pickle.dump(svd, open(file, 'wb'))

    df_ret = pd.DataFrame(df_svd, columns=[f"{text}_{i}" for i in range(n_components)])
    return df_ret

# %%
# 指定のカラムをベクトル化して結合
for col, n_components in [("title", 20), ("body", 20), ("tags", 20)]:
    df_vec = vectorize_text(col, n_components)
    # ベクトル化したカラムを結合
    df = pd.concat([df, df_vec], axis=1)
    # 欠損値を含む行を削除
    df = df.dropna()
    # 元のカラムを削除
    df = df.drop(col, axis=1)
df.head()
# Out:
#    likes_count  created_time  followers_count  organization  items_count  \
# 0          1.0            23             43.0             1         97.0
# 1          5.0            23              2.0             0          7.0
# 2          3.0            23            157.0             0         65.0
# 3          0.0            23              1.0             0         10.0
# 4          0.0            23              3.0             0         11.0
#
#    created_days_ago  created_month       title_0       title_1       title_2  \
# 0              1040              1 -4.500403e-16 -1.272622e-14  8.290435e-14
# 1              1040              1  5.157261e-04  8.719502e-04  5.994290e-04
# 2              1040              1  1.985387e-06  9.942188e-07  3.635362e-06
# 3              1040              1  1.153929e-03  1.424405e-03  2.888412e-03
# 4              1040              1  1.087070e-04  1.237601e-04  1.992466e-04
#
#         title_3       title_4       title_5       title_6       title_7  \
# 0 -5.265333e-14 -4.472895e-14  4.400130e-14  2.964003e-14  2.400184e-13
# 1  1.790704e-03  3.987319e-03 -1.195041e-03  1.229403e-03  2.457885e-03
# 2  5.121854e-06  7.352084e-06  6.192135e-06  1.924672e-05  2.473045e-05
# 3  6.182741e-04  5.034951e-03  2.271755e-03  3.731945e-03  3.862946e-03
# 4  7.430572e-04  2.407062e-04  3.108348e-05  2.223759e-04  3.543706e-04
#
#         title_8       title_9      title_10      title_11      title_12  \
# 0 -4.000405e-13 -1.618981e-13  2.944846e-13  3.651733e-13  9.342856e-13
# 1  4.648645e-03  2.567079e-03  1.697939e-02 -3.971771e-03  5.568064e-03
# 2  1.166271e-05  2.761942e-06  1.583611e-04  3.560817e-04 -1.666184e-05
# 3  1.307373e-02  2.729795e-02  4.827855e-02 -1.835525e-02 -4.892313e-03
# 4  4.571518e-04  1.027017e-04  9.067908e-04  1.242775e-04  5.016158e-04
#
#        title_13      title_14      title_15      title_16      title_17  \
# 0  2.177648e-14  1.186000e-12 -7.561057e-13 -5.044475e-14 -2.154481e-12
# 1  5.167523e-02  1.538894e-02 -1.747872e-02 -7.150699e-02 -7.751317e-02
# 2 -2.614952e-05  4.400083e-06 -2.193658e-05  2.240486e-05  3.203007e-05
# 3 -1.099357e-02 -3.432294e-04 -8.475488e-03  7.095404e-03 -4.172485e-03
# 4  2.069098e-03  7.613731e-04 -7.709221e-04 -1.350447e-03  1.404489e-06
#
#        title_18      title_19    body_0        body_1    body_2    body_3  \
# 0  5.203612e-14 -2.046689e-12  0.006063  9.050917e-07  0.004740  0.004435
# 1  3.230485e-01 -6.614566e-02  0.034778 -2.825193e-03  0.007545  0.001325
# 2  8.196343e-06  2.379514e-06  0.156661 -4.337546e-02 -0.023106 -0.028917
# 3  9.785167e-03  3.241514e-02  0.065840 -2.708442e-03  0.075463 -0.000431
# 4 -1.592323e-03  3.283036e-03  0.178239 -5.287209e-02 -0.061289  0.002612
#
#      body_4    body_5    body_6    body_7    body_8    body_9   body_10  \
# 0 -0.001534  0.002026 -0.011782 -0.002644  0.004100 -0.003432  0.018672
# 1 -0.002589  0.005266 -0.004411 -0.014544  0.005039  0.017687  0.004082
# 2  0.000793 -0.014235  0.026373  0.011160  0.007820 -0.005046  0.000739
# 3 -0.051652 -0.005452 -0.017909  0.002922  0.033791  0.075111 -0.032922
# 4 -0.005922 -0.000824 -0.004359  0.000821 -0.002348  0.000506 -0.000293
#
#     body_11   body_12   body_13   body_14   body_15   body_16   body_17  \
# 0 -0.006545 -0.003133 -0.008534 -0.009266 -0.004357 -0.001449 -0.004306
# 1 -0.005600  0.012383  0.001789  0.008917 -0.000145 -0.004310  0.005650
# 2 -0.004070 -0.017670  0.026946  0.015278 -0.020146  0.009176  0.031891
# 3 -0.037875 -0.024627 -0.081292 -0.102682  0.036988 -0.004385  0.027115
# 4  0.002239 -0.000778  0.009380  0.019518  0.000206 -0.008454  0.011051
#
#     body_18   body_19        tags_0        tags_1    tags_2        tags_3  \
# 0  0.004600 -0.002695  1.368589e-05 -5.982908e-09  0.000005 -4.152438e-07
# 1  0.000052 -0.004166  1.201126e-03  2.715158e-03  0.001893  6.633753e-03
# 2  0.014355 -0.001328  8.599358e-07  2.391348e-06  0.000002  8.640996e-07
# 3 -0.007220 -0.114612  3.459076e-04  4.550913e-04  0.001348  2.829116e-03
# 4 -0.006943 -0.009098  9.031720e-04  2.821084e-03  0.008449  4.004773e-03
#
#          tags_4        tags_5        tags_6        tags_7    tags_8  \
# 0 -5.830805e-07 -7.346930e-06 -1.226697e-07 -3.885491e-06  0.000037
# 1 -5.441147e-03 -4.447897e-03  7.987663e-03  3.491092e-02  0.010981
# 2 -1.256343e-06  4.544364e-08 -5.950063e-07 -1.658783e-07  0.000003
# 3 -1.855572e-03  1.471222e-03  1.124201e-03 -9.308493e-05  0.000411
# 4 -6.773948e-04  3.460808e-03 -1.404576e-03  4.059176e-04  0.001723
#
#          tags_9   tags_10       tags_11       tags_12   tags_13   tags_14  \
# 0 -7.453559e-08  0.000004 -6.674596e-07  1.235866e-07  0.000004  0.000003
# 1 -3.724159e-03  0.111790  1.485597e-01  2.813387e-03  0.000618 -0.002093
# 2  2.620177e-07  0.000001 -1.386693e-06  6.862651e-06 -0.000002 -0.000001
# 3 -1.102464e-04  0.001032 -1.434920e-03  5.135548e-03 -0.001171 -0.000421
# 4  7.199191e-04  0.000515  6.259154e-04  1.625680e-04  0.001551  0.003443
#
#     tags_15   tags_16   tags_17   tags_18   tags_19
# 0  0.000007  0.000004 -0.000003  0.000004  0.000003
# 1  0.000319  0.330533  0.027272 -0.136634 -0.000002
# 2  0.000009  0.000013 -0.000010  0.000002  0.000011
# 3  0.000666  0.000997 -0.003931 -0.004468  0.018866
# 4  0.000324 -0.000560 -0.002519  0.003965  0.003959

# %%
# trainとtestに分割する(likes_countを目的変数とする)
from sklearn.model_selection import train_test_split
train, test = train_test_split(df, test_size=0.3, random_state=0)
train_y = train["likes_count"]
train_X = train.drop(["likes_count"], axis=1)
test_y = test["likes_count"]
test_X = test.drop(["likes_count"], axis=1)

# %%
# Randomforestでモデルの学習
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor()
model.fit(train_X, train_y)

# テストデータの予測
y_pred = model.predict(test_X)

# %%
file = '../app/model/trained_rfr_model.pkl'
pickle.dump(model, open(file, 'wb'))

# %%
model_rfr = pickle.load(open(file, 'rb'))
model_rfr.predict(test_X.iloc[[0]])
# Out:
# array([4.4])
